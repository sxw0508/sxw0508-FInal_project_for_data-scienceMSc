# %%
import google.generativeai as genai
import os


os.environ['API_KEY'] = 'AIzaSyDMZKBp--GxEMqmrSJw8I2qRTCZnQZSwjw'
genai.configure(api_key=os.environ["API_KEY"])

# %%
import re
import requests
import os
from datetime import datetime

from bs4 import BeautifulSoup
from bs4.element import Tag

import pandas as pd
# Out:
# D:\conda\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
# !playwright install

# %%
import os
from dotenv import load_dotenv
from scrapegraphai.graphs import SmartScraperGraph
from scrapegraphai.utils import prettify_exec_info
import requests

load_dotenv()
api_key = os.getenv('API_KEY')
graph_config = {
    "llm": {
        "model": "gemini-pro",
        "api_key": api_key,  
    },
}


response = requests.get("https://www.yappy.com/uk/dogs/breeds")
response.raise_for_status()  # Ensure we raise an error for bad responses
html_content = response.text

smart_scraper_graph = SmartScraperGraph(
    prompt=" List me all the dog breeds",
    source=html_content,  
    config=graph_config
)
result = smart_scraper_graph.run()
print(result)
# Out:
# {'dog_breeds': ['Affenpinscher', 'Afghan Hound', 'Airedale Terrier', 'Akita', 'Alaskan Klee Kai', 'Alaskan Malamute', 'American Bulldog', 'American Cocker Spaniel', 'American Eskimo Dog', 'American Hairless Terrier', 'American Leopard Hound', 'American Pit Bull Terrier', 'American Staffordshire Terrier', 'American Water Spaniel', 'Anatolian Shepherd Dog', 'Aussiedoodle', 'Australian Cattle Dog', 'Australian Kelpie', 'Australian Labradoodle', 'Australian Shepherd', 'Australian Silky Terrier', 'Australian Terrier', 'Australian Working Kelpie', 'Azawakh', 'Basenji', 'Bassador', 'Basset Bleu De Gascogne', 'Basset Fauve De Bretagne', 'Basset Hound', 'Bassugg', 'Bavarian Mountain Hound', 'Beagador', 'Beagle', 'Beaglier', 'Bearded Collie', 'Beauceron', 'Bedlington Terrier', 'Bedlington Whippet', 'Belgian Groenendael', 'Belgian Laekenois', 'Belgian Malinois', 'Belgian Shepherd', 'Belgian Tervuren', 'Bergamasco', 'Bernedoodle', 'Bernese Mountain Dog', 'Bichon Frise', 'Bichon Yorkie', 'Bich-po
# ...

# %%
print(response.text)
# Out:
# <!doctype html>
# <html lang="en-gb" class="region-uk">
# <head>
#
#
#     <link rel="alternate" href="https://www.yappy.com/" hreflang="x-default" />
#     <meta http-equiv="content-language" content="en-gb">
#         <link rel="alternate" href="https://www.yappy.com/uk/dogs/breeds" hreflang="en-gb" />
#         <link rel="alternate" href="https://www.yappy.com/us/dogs/breeds" hreflang="en-us" />
#
#
#         <!-- Google Tag Manager -->
#         <script>
#             (function (w, d, s, l, i) {
#                 w[l] = w[l] || []; w[l].push({
#                     'gtm.start':
#                         new Date().getTime(), event: 'gtm.js'
#                 }); var f = d.getElementsByTagName(s)[0],
#                     j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#                         'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
# ...

# %%
import json
with open("results.json", 'w', encoding='utf-8') as f:
      json.dump(result,f, indent=4)

# %%
import os
from dotenv import load_dotenv
from scrapegraphai.graphs import SmartScraperGraph
from scrapegraphai.utils import prettify_exec_info
import json

load_dotenv()

openai_key = os.getenv("OPENAI_APIKEY")
response = requests.get("https://www.yappy.com/uk/dogs/breeds")
response.raise_for_status()  # Ensure we raise an error for bad responses
html_content = response.text

graph_config = {
   "llm": {
      "api_key": openai_key,
      "model": "gpt-3.5-turbo",
   },
}

# ************************************************
# Create the SmartScraperGraph instance and run it
# ************************************************

smart_scraper_graph = SmartScraperGraph(
   prompt="List me all the products name with their price.",
   # also accepts a string with the already downloaded HTML code
   source=html_content,
   config=graph_config
)


result = smart_scraper_graph.run()
with open("results_openai.json", 'w', encoding='utf-8') as f:
      json.dump(result,f, indent=4)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[5], line 32
#      21 # ************************************************
#      22 # Create the SmartScraperGraph instance and run it
#      23 # ************************************************
#      25 smart_scraper_graph = SmartScraperGraph(
#      26    prompt="List me all the products name with their price.",
#      27    # also accepts a string with the already downloaded HTML code
#      28    source=html_content,
#      29    config=graph_config
#      30 )
# ---> 32 result = smart_scraper_graph.run()
#      33 with open("results_openai.json", 'w', encoding='utf-8') as f:
#      34       json.dump(result,f, indent=4)
#
# File D:\conda\Lib\site-packages\scrapegraphai\graphs\smart_scraper_graph.py:120, in SmartScraperGraph.run(self)
#     112 """
# ...

# %%
base_url = 'https://www.yappy.com/uk/dogs/breeds'
response = requests.get(base_url)
html_content = response.content

# %%
model = genai.GenerativeModel('gemini-1.5-flash')

prompt = f"Write python code that returns all the dog breed and the urls for each dog breed in this page in Json format (do not include the html in the code): {html_content}"

response = model.generate_content(prompt)

# %%
print(response.text[-50:])
# Out:
#  },
#     {
#       "breed": "Saluki",
#       "url": "/

# %%
model = genai.GenerativeModel('gemini-1.5-flash')

prompt = f"Find all the dog breed and the urls for each breed in this page: {html_content}"

response = model.generate_content(prompt)

# %%
response_text = response.text.strip('```json\n').strip('```')

# Step 2: 替换转义字符
response_text = response_text.replace('\\n', '\n').replace('\\"', '"').replace("\\'", "'")
def clean_json_string(json_string):
    # 使用正则表达式去掉尾随逗号
    json_string = re.sub(r',\s*([}\]])', r'\1', json_string)
    return json_string

# %%
response_text = response.text.strip('```json\n').strip('```')
cleaned_text = clean_json_string(response_text)

# 尝试解析清理后的JSON字符串
try:
    json_data = json.loads(cleaned_text)
    # 格式化输出
    formatted_json = json.dumps(json_data, indent=2)
    print("Formatted JSON:\n", formatted_json)
except json.JSONDecodeError as e:
    # 如果解析失败，打印出详细信息
    print(f"Failed to decode JSON: {e}")
    lines = cleaned_text.split('\n')
    # 打印出错误附近的几行内容，帮助调试
    for i, line in enumerate(lines):
        if i > e.lineno - 5 and i < e.lineno + 5:
            print(f"{i+1}: {line}")

# 输出清理后的JSON字符串
print("Cleaned JSON:\n", cleaned_text)
# Out:
# Failed to decode JSON: Expecting value: line 801 column 11 (char 25690)
# 798:           "name": "Bichon Yorkie",
# 799:           "url": "/uk/bichonyorkie",
# 800:           "image": "https://images.yappy.com/yappicon/bichonyorkie/bichonyorkie-01.png"
# 801:         },
# Cleaned JSON:
#  {
#   "title": "Dog Breeds A-Z | Yappy.com",
#   "description": "Shop by Breed and create a tailor-made shop for your dog. Beds, Biscuits, Bowls, Cushions, Leads, Toys and much more.",
#   "canonical_url": "https://www.yappy.com/uk/dogs/breeds",
#   "logo": "https://images.yappy.com/images/yappy-purple.svg",
#   "social_links": [
#     {
#       "name": "Facebook",
#       "url": "https://www.facebook.com/yappycom/"
#     },
#     {
#       "name": "Instagram",
#       "url": "https://www.instagram.com/yappy_com/"
#     },
#     {
#       "name": "Tik Tok",
#       "url": "https://www.tiktok.com/@yappy_com"
#     }
#   ],
#   "contact_info": {
#     "email": "help@yappy.com",
# ...

# %%
model = genai.GenerativeModel('gemini-1.5-flash')

prompt = f"scrap information about dog breed from this page,: {html_content}"

response1 = model.generate_content(prompt)

# %%
print(response1.text[:50])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(response1.text[:50])
#
# NameError: name 'response1' is not defined

# %%
import re
from bs4 import BeautifulSoup

# Assuming response1.text contains the raw HTML content
raw_html = response1.text

# Use BeautifulSoup to parse the HTML
soup = BeautifulSoup(raw_html, 'html.parser')

# Extract the relevant content
# For this example, let's assume you want to extract information about dog breeds

# Find all relevant tags, assuming the dog breed information is in <div> tags with a specific class
breed_divs = soup.find_all('div', class_='breed-info')  # Replace 'breed-info' with the actual class name if different

# Extract and print the text content of these tags
breeds = []
for div in breed_divs:
    breed_name = div.find('h2').text  # Assuming breed names are in <h2> tags
    breed_description = div.find('p').text  # Assuming breed descriptions are in <p> tags
    breeds.append({'name': breed_name, 'description': breed_description})

# Display the extracted breeds
for breed in breeds:
    print(f"Breed Name: {breed['name']}\nDescription: {breed['description']}\n")

# %%
# Out:
# > ```python
# > import re
# > from bs4 import BeautifulSoup
# >
# ...
