# %%
from scrapegraphai.graphs import DepthSearchGraph
import nest_asyncio

nest_asyncio.apply()


open_ai_key = "sk-YApzULCHGCaBlngoQKKjQqI9eMTjAlZsyBRIae3dMM8WvXXX"
graph_config = {
    "llm": {
        "api_key": open_ai_key,
        "model": "openai/gpt-4o",
        "base_url": "https://api.chatanywhere.tech/v1"
    },
    
    "depth": 2,  
    "only_inside_links": True,
    "verbose": True,
    "headless": True
    
    

    
}


search_graph = DepthSearchGraph(
    prompt="List me all the projects with their description",
    source="https://perinim.github.io",
    config=graph_config
)

result = search_graph.run()
print(result)
# Out:
# --- Executing FetchLevelK Node ---
# Fetching HTML content from: https://perinim.github.io
# Fetched content for https://perinim.github.io at depth 1
# Extracted 12 links.
# Analyzing 12 links using LLM.
# LLM approved link: https://perinim.github.io/
# LLM rejected link: #
# LLM approved link: https://perinim.github.io/projects/
# LLM rejected link: https://perinim.github.io/competitions/
# LLM approved link: https://perinim.github.io/cv/
# LLM rejected link: mailto:%70%65%72%69%6E%69%6D.%39%38@%67%6D%61%69%6C.%63%6F%6D
# LLM rejected link: https://github.com/PeriniM
# LLM rejected link: https://www.linkedin.com/in/perinim
# LLM rejected link: https://twitter.com/Perinim_98
# LLM rejected link: https://jekyllrb.com/
# LLM rejected link: https://github.com/alshedivat/al-folio
# LLM rejected link: https://pages.github.com/
# Adding link to new documents: https://perinim.github.io/
# Adding link to new documents: https://perinim.github.io/projects/
# Adding link to new documents: https://perinim.github.io/cv/
# Fetching HTML content from: https://perinim.github.io/
# Fetched content for https://perinim.github.io/ at depth 2
# Extracted 12 links.
# Fetching HTML content from: https://perinim.github.io/projects/
# Fetched content for https://perinim.github.io/projects/ at depth 2
# Extracted 13 links.
# Fetching HTML content from: https://perinim.github.io/cv/
# Fetched content for https://perinim.github.io/cv/ at depth 2
# Extracted 25 links.
# --- Executing ParseNodeDepthK Node ---
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 32
#       8 graph_config = {
#       9     "llm": {
#      10         "api_key": open_ai_key,
#    (...)
#      22
#      23 }
#      26 search_graph = DepthSearchGraph(
#      27     prompt="List me all the projects with their description",
#      28     source="https://perinim.github.io",
#      29     config=graph_config
#      30 )
# ---> 32 result = search_graph.run()
#      33 print(result)
#
# File ~\Desktop\study\project\final_codepart\scrapegraphai\graphs\depth_search_graph.py:147, in DepthSearchGraph.run(self)
#     139 """
#     140 Executes the scraping process and returns the generated code.
#     141
#     142 Returns:
#     143     str: The generated code.
#     144 """
#     146 inputs = {"user_prompt": self.prompt, self.input_key: self.source}
# --> 147 self.final_state, self.execution_info = self.graph.execute(inputs)
#     149 docs = self.final_state.get("answer", "No answer")
#     151 return docs
#
# File ~\Desktop\study\project\final_codepart\scrapegraphai\graphs\base_graph.py:284, in BaseGraph.execute(self, initial_state)
#     282     return (result["_state"], [])
#     283 else:
# --> 284     return self._execute_standard(initial_state)
#
# File ~\Desktop\study\project\final_codepart\scrapegraphai\graphs\base_graph.py:198, in BaseGraph._execute_standard(self, initial_state)
#     185     graph_execution_time = time.time() - start_time
#     186     log_graph_execution(
#     187         graph_name=self.graph_name,
#     188         source=source,
#    (...)
#     196         exception=str(e)
#     197     )
# --> 198     raise e
#     199 node_exec_time = time.time() - curr_time
#     200 total_exec_time += node_exec_time
#
# File ~\Desktop\study\project\final_codepart\scrapegraphai\graphs\base_graph.py:182, in BaseGraph._execute_standard(self, initial_state)
#     180 with self.callback_manager.exclusive_get_callback(llm_model, llm_model_name) as cb:
#     181     try:
# --> 182         result = current_node.execute(state)
#     183     except Exception as e:
#     184         error_node = current_node.node_name
#
# File ~\Desktop\study\project\final_codepart\scrapegraphai\nodes\parse_node_depth_k_node.py:62, in ParseNodeDepthK.execute(self, state)
#      59 documents = input_data[0]
#      61 for doc in documents:
# ---> 62     document_md = Html2TextTransformer(ignore_links=True).transform_documents(doc["document"])
#      63     doc["document"] = document_md[0].page_content
#      65 state.update({self.output[0]: documents})
#
# TypeError: 'Document' object is not subscriptable

# %%
from scrapegraphai.graphs import DepthSearchGraph
import nest_asyncio

nest_asyncio.apply()


open_ai_key = "sk-YApzULCHGCaBlngoQKKjQqI9eMTjAlZsyBRIae3dMM8WvXXX"
graph_config = {
    "llm": {
        "api_key": open_ai_key,
        "model": "openai/gpt-4o",
        "base_url": "https://api.chatanywhere.tech/v1"
    },
    
    "depth": 2,  
    "only_inside_links": True,
    "verbose": True,
    "headless": True
    
    

    
}


search_graph = DepthSearchGraph(
    prompt="List me all the projects with their description",
    source="https://perinim.github.io",
    config=graph_config
)

result = search_graph.run()
print(result)
# Out:
# --- Executing FetchLevelK Node ---
# Fetching HTML content from: https://perinim.github.io
# Extracted 12 links.
# Analyzing 12 links using LLM.
# LLM rejected link: https://perinim.github.io/
# LLM approved link: #
# LLM rejected link: https://perinim.github.io/projects/
# LLM rejected link: https://perinim.github.io/competitions/
# LLM approved link: https://perinim.github.io/cv/
# LLM rejected link: mailto:%70%65%72%69%6E%69%6D.%39%38@%67%6D%61%69%6C.%63%6F%6D
# LLM approved link: https://github.com/PeriniM
# LLM approved link: https://www.linkedin.com/in/perinim
# LLM rejected link: https://twitter.com/Perinim_98
# LLM approved link: https://jekyllrb.com/
# LLM approved link: https://github.com/alshedivat/al-folio
# LLM approved link: https://pages.github.com/
# Fetching HTML content from: https://perinim.github.io/cv/
# Extracted 25 links.
# Analyzing 25 links using LLM.
# LLM rejected link: https://perinim.github.io/
# LLM rejected link: https://perinim.github.io/
# LLM approved link: #
# LLM rejected link: https://perinim.github.io/projects/
# LLM rejected link: https://perinim.github.io/competitions/
# LLM rejected link: https://perinim.github.io/cv/
# LLM rejected link: #general-information
# LLM rejected link: #education
# LLM approved link: #work-experience
# LLM rejected link: #honors-and-awards
# LLM rejected link: #interests-hobbies
# LLM rejected link: https://www.bluetensor.ai/
# LLM rejected link: https://www.econox.nl/
# LLM rejected link: https://www.infominds.eu/
# LLM approved link: https://www.matrycs.eu/
# LLM rejected link: https://www.jeniot.it/
# LLM rejected link: https://www.soi.unitn.it/
# LLM rejected link: https://www.dana.com/
# LLM approved link: https://www.dana.com/
# LLM rejected link: https://www.dana.com/
# LLM approved link: https://www.unipd.it/en/
# LLM rejected link: https://github.com/PeriniM
# LLM approved link: https://jekyllrb.com/
# LLM approved link: https://github.com/alshedivat/al-folio
# LLM approved link: https://pages.github.com/
# --- Executing ParseNodeDepthK Node ---
# --- Executing DESCRIPTION Node ---
# Processing chunks: 100%|█████████████████████████████████████████████████████████████████████████| 2/2 [00:00<?, ?it/s]
# --- Executing RAG Node ---
# --- Executing GANLK Node ---
# Processing chunks: 100%|█████████████████████████████████████████████████████████████████████████| 2/2 [00:00<?, ?it/s]
# {'projects': 'NA'}

# %% [markdown]
# custom_graph:

# %%
from scrapegraphai.graphs import CustomGraph
import nest_asyncio

nest_asyncio.apply()



open_ai_key = "sk-YApzULCHGCaBlngoQKKjQqI9eMTjAlZsyBRIae3dMM8WvXXX"
graph_config = {
    "llm": {
        "api_key": open_ai_key,
        "model": "openai/gpt-4o",
        "base_url": "https://api.chatanywhere.tech/v1"
    },
    
    "depth": 2,  
    "only_inside_links": True,
    "verbose": True,
    "headless": True
    
    
}
graph = CustomGraph(
    prompt="access the project page and list me all the projects with their description",
    source="https://perinim.github.io/",
    config=graph_config
)

result = graph.run()
print(result)
# Out:
# --- Executing FetchLevelK Node ---
# Fetching HTML content from: https://perinim.github.io/
# Fetched content for https://perinim.github.io/ at depth 1
# Extracted 12 links.
# Analyzing 12 links using LLM.
# LLM approved link: https://perinim.github.io/
# LLM rejected link: #
# LLM approved link: https://perinim.github.io/projects/
# LLM approved link: https://perinim.github.io/competitions/
# LLM approved link: https://perinim.github.io/cv/
# LLM rejected link: mailto:%70%65%72%69%6E%69%6D.%39%38@%67%6D%61%69%6C.%63%6F%6D
# LLM rejected link: https://github.com/PeriniM
# LLM rejected link: https://www.linkedin.com/in/perinim
# LLM rejected link: https://twitter.com/Perinim_98
# LLM rejected link: https://jekyllrb.com/
# LLM rejected link: https://github.com/alshedivat/al-folio
# LLM rejected link: https://pages.github.com/
# Adding link to new documents: https://perinim.github.io/projects/
# Adding link to new documents: https://perinim.github.io/competitions/
# Adding link to new documents: https://perinim.github.io/cv/
# Fetching HTML content from: https://perinim.github.io/projects/
# Fetched content for https://perinim.github.io/projects/ at depth 2
# Extracted 13 links.
# Fetching HTML content from: https://perinim.github.io/competitions/
# Fetched content for https://perinim.github.io/competitions/ at depth 2
# Extracted 27 links.
# Fetching HTML content from: https://perinim.github.io/cv/
# Fetched content for https://perinim.github.io/cv/ at depth 2
# Extracted 25 links.
# --- Executing ParseNode Node ---
# {'user_prompt': 'access the project page and list me all the projects with their description', 'url': 'https://perinim.github.io/', 'doc': [Document(metadata={'source': 'https://perinim.github.io/'}, page_content='<!DOCTYPE html><html lang="en" class=""><head> <meta http-equiv="Content-Type" content="text/html; charset=UTF-8"> <meta charset="utf-8"> <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <title>Marco Perini</title> <meta name="author" content="Marco Perini"> <meta name="description" content="Personal Porfolio Website "> <meta name="keywords" content="jekyll, jekyll-theme, academic-website, portfolio-website, robotics, machine-learning, computer-vision, artificial-intelligence, deep-learning, data-science, data-analysis, data-visualization, reinforcement-learning, computer-science, computer-graphics, computer-architecture, computer-networks, computer-security, computer-aided-design, computer-algebra, computer-alg, hardware"> <link rel="stylesheet" href="/assets/css/bootstrap.min.css?a4b3f509e79c54a512b890d73235ef04"> <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/mdbootstrap@4.20.0/css/mdb.min.css" integrity="sha256-jpjYvU3G3N6nrrBwXJoVEYI/0zw8htfFnhT9ljN3JJw=" crossorigin="anonymous"> <link defer="" rel="stylesheet" href="https://unpkg.com/bootstrap-table@1.22.1/dist/bootstrap-table.min.css"> <link rel="stylesheet" href="/assets/css/academicons.min.css?f0b7046b84e425c55f3463ac249818f5"> <link rel="stylesheet" type="text/css" href="https://fonts.googleapis.com/css?family=Roboto:300,400,500,700|Roboto+Slab:100,300,400,500,700|Material+Icons"> <link rel="stylesheet" href="/assets/css/jekyll-pygments-themes-github.css?19f3075a2d19613090fe9e16b564e1fe" media="" id="highlight_theme_light"> <link rel="shortcut icon" href="data:image/svg+xml,<svg%20xmlns=%22http://www.w3.org/2000/svg%22%20viewBox=%220%200%20100%20100%22><text%20y=%22.9em%22%20font-size=%2290%22>%F0%9F%A6%BE</text></svg>"> <link rel="stylesheet" href="/assets/css/main.css?d41d8cd98f00b204e9800998ecf8427e"> <link rel="canonical" href="https://perinim.github.io/"> <link rel="stylesheet" href="/assets/css/jekyll-pygments-themes-native.css?e74e74bf055e5729d44a7d031a5ca6a5" media="none" id="highlight_theme_dark"> <script src="/assets/js/theme.js?96d6b3e1c3604aca8b6134c7afdd5db6"></script> <script src="/assets/js/dark_mode.js?9b17307bb950ffa2e34be0227f53558f"></script> <style type="text/css">/* Chart.js */\n@-webkit-keyframes chartjs-render-animation{from{opacity:0.99}to{opacity:1}}@keyframes chartjs-render-animation{from{opacity:0.99}to{opacity:1}}.chartjs-render-monitor{-webkit-animation:chartjs-render-animation 0.001s;animation:chartjs-render-animation 0.001s;}</style><style type="text/css">.medium-zoom-overlay{position:fixed;top:0;right:0;bottom:0;left:0;opacity:0;transition:opacity .3s;will-change:opacity}.medium-zoom--opened .medium-zoom-overlay{cursor:pointer;cursor:zoom-out;opacity:1}.medium-zoom-image{cursor:pointer;cursor:zoom-in;transition:transform .3s cubic-bezier(.2,0,.2,1)!important}.medium-zoom-image--hidden{visibility:hidden}.medium-zoom-image--opened{position:relative;cursor:pointer;cursor:zoom-out;will-change:transform}</style><script id="altmetric-embed-js" src="https://d1bxh8uas1mnw7.cloudfront.net/assets/altmetric_badges-e8c6816abd50a76f6c51292a940cd903f1d7767d11fcfee92c0e65948faf4a1b.js"></script><style type="text/css">.CtxtMenu_InfoClose {  top:.2em; right:.2em;}\n.CtxtMenu_InfoContent {  overflow:auto; text-align:left; font-size:80%;  padding:.4em .6em; border:1px inset; margin:1em 0px;  max-height:20em; max-width:30em; background-color:#EEEEEE;  white-space:normal;}\n.CtxtMenu_Info.CtxtMenu_MousePost {outline:none;}\n.CtxtMenu_Info {  position:fixed; left:50%; width:auto; text-align:center;  border:3px outset; padding:1em 2em; background-color:#DDDDDD;  color:black;  cursor:default; font-family:message-box; font-size:120%;  font-style:nor ...
# --- Executing RAG Node ---
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 29
#       9 graph_config = {
#      10     "llm": {
#      11         "api_key": open_ai_key,
#    (...)
#      21
#      22 }
#      23 graph = CustomGraph(
#      24     prompt="access the project page and list me all the projects with their description",
#      25     source="https://perinim.github.io/",
#      26     config=graph_config
#      27 )
# ---> 29 result = graph.run()
#      30 print(result)
#
# File ~\Desktop\study\project\final_codepart\scrapegraphai\graphs\custom_graph.py:187, in CustomGraph.run(self)
#     180 """
#     181 Executes the graph and returns the generated answer.
#     182
#     183 Returns:
#     184     str: The generated answer or a fallback message.
#     185 """
#     186 inputs = {"user_prompt": self.prompt, self.input_key: self.source}
# --> 187 self.final_state, self.execution_info = self.graph.execute(inputs)
#     188 return self.final_state.get("answer", "No answer found.")
#
# File ~\Desktop\study\project\final_codepart\scrapegraphai\graphs\base_graph.py:284, in BaseGraph.execute(self, initial_state)
#     282     return (result["_state"], [])
#     283 else:
# --> 284     return self._execute_standard(initial_state)
#
# File ~\Desktop\study\project\final_codepart\scrapegraphai\graphs\base_graph.py:198, in BaseGraph._execute_standard(self, initial_state)
#     185     graph_execution_time = time.time() - start_time
#     186     log_graph_execution(
#     187         graph_name=self.graph_name,
#     188         source=source,
#    (...)
#     196         exception=str(e)
#     197     )
# --> 198     raise e
#     199 node_exec_time = time.time() - curr_time
#     200 total_exec_time += node_exec_time
#
# File ~\Desktop\study\project\final_codepart\scrapegraphai\graphs\base_graph.py:182, in BaseGraph._execute_standard(self, initial_state)
#     180 with self.callback_manager.exclusive_get_callback(llm_model, llm_model_name) as cb:
#     181     try:
# --> 182         result = current_node.execute(state)
#     183     except Exception as e:
#     184         error_node = current_node.node_name
#
# File ~\Desktop\study\project\final_codepart\scrapegraphai\nodes\rag_node.py:27, in RAGNode.execute(self, state)
#      23 self.logger.info(f"--- Executing {self.node_name} Node ---")
#      25 client = self.create_qdrant_client()
# ---> 27 docs = [elem.get("summary") for elem in state.get("docs")]
#      28 ids = [i for i in range(1, len(state.get("docs"))+1)]
#      30 if state.get("embeddings"):
#
# TypeError: 'NoneType' object is not iterable

# %%
from scrapegraphai.graphs import CustomGraph
import nest_asyncio

nest_asyncio.apply()


open_ai_key = "sk-YApzULCHGCaBlngoQKKjQqI9eMTjAlZsyBRIae3dMM8WvXXX"
graph_config = {
    "llm": {
        "api_key": open_ai_key,
        "model": "openai/gpt-4o",
        "base_url": "https://api.chatanywhere.tech/v1"
    },
    
    "depth": 2,  
    "only_inside_links": True,
        
    "verbose": True,
    "headless": True
    
}


search_graph = CustomGraph(
    prompt="List me all the projects with their description",
    source="https://perinim.github.io/",
    config=graph_config
)

result = search_graph.run()
print(result)
# Out:
# --- Executing FetchLevelK Node ---
# Fetching HTML content from: https://perinim.github.io/projects
# Fetched content for https://perinim.github.io/projects at depth 1
# Extracted 13 links.
# Analyzing 13 links using LLM.
# LLM rejected link: https://perinim.github.io/
# LLM rejected link: https://perinim.github.io/
# LLM rejected link: #
# LLM approved link: https://perinim.github.io/projects/
# LLM rejected link: https://perinim.github.io/competitions/
# LLM rejected link: https://perinim.github.io/cv/
# LLM approved link: https://perinim.github.io/projects/rotary-pendulum-rl/
# LLM rejected link: https://github.com/PeriniM/DQN-SwingUp
# LLM rejected link: https://github.com/PeriniM/Multi-Agents-HAED
# LLM approved link: https://perinim.github.io/projects/wireless-esc-drone/
# LLM rejected link: https://jekyllrb.com/
# LLM rejected link: https://github.com/alshedivat/al-folio
# LLM rejected link: https://pages.github.com/
# --- Executing ParseNode Node ---
# --- Executing RAG Node ---
# --- Executing GenerateAnswer Node ---
# {'projects': [{'name': 'Rotary Pendulum RL', 'description': 'Open Source project aimed at controlling a real life rotary pendulum using RL algorithms'}, {'name': 'DQN Implementation from scratch', 'description': 'Developed a Deep Q-Network algorithm to train a simple and double pendulum'}, {'name': 'Multi Agents HAED', 'description': 'University project which focuses on simulating a multi-agent system to perform environment mapping. Agents, equipped with sensors, explore and record their surroundings, considering uncertainties in their readings.'}, {'name': 'Wireless ESC for Modular Drones', 'description': 'Modular drone architecture proposal and proof of concept. The project received maximum grade.'}]}

# %% [markdown]
# ### for custom graph ，attempts 10 times, success 5 times

# %% [markdown]
# ## baseline:

# %%
import re
import requests
import os
from datetime import datetime

from bs4 import BeautifulSoup
from bs4.element import Tag

import pandas as pd
from openai import OpenAI
#Call the openai api directly
# Initialize OpenAI client
open_ai_key = "sk-YApzULCHGCaBlngoQKKjQqI9eMTjAlZsyBRIae3dMM8WvXXX"
client = OpenAI(
    api_key=open_ai_key,
    base_url="https://api.chatanywhere.tech/v1"
)

def get_scraper_task(instruction):
    """
    Generates a web scraping task based on the provided instruction.

    Args:
        instruction (str): The instruction containing the task details and URL.

    Returns:
        str: The response content from the model or an error message if the API call fails.
    """
    try:
        # Call the OpenAI API with the provided instruction
        completion = client.chat.completions.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": "You are a web scraper. Follow the prompt in instruction to do task with the URL in the instruction.(note：You can use any way to get the html of a web page)"},
                {"role": "user", "content": instruction}
            ]
        )
        
        # Return the content of the model's response
        return completion.choices[0].message.content
    except Exception as e:
        return f"Error: {str(e)}"
response = requests.get("https://perinim.github.io/")
response.raise_for_status()  # Ensure we raise an error for bad responses
html_content = response.text
import json
instruction = {
    "prompt": "List me all the projects with their description",
    "URL": "https://perinim.github.io",
    "html":html_content,
}
instruction_str = json.dumps(instruction)
response = get_scraper_task(instruction_str)
print(response)
# Out:
# To list all the projects with their descriptions from the given website, you need to navigate to the Projects section. Unfortunately, the HTML code you provided does not contain the detailed content of the Projects page. The list of projects is likely under the "/projects/" path on the website.
#
# Please follow these general steps:
#
# 1. Go to the URL: [https://perinim.github.io/projects/](https://perinim.github.io/projects/).
# 2. Analyze the HTML of that specific page to scrape the list of projects and their descriptions.
#
# If you have access to the HTML content of the '/projects/' page or need further assistance in scraping the data, please provide that content or let me know how I can further assist you.

# %% [markdown]
# ### fail
